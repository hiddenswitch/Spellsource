# %% [markdown]
# # Printing Cards from Spellsource
#
# In this example, we'll print all the uncollectible cards from Spellsource.
#
# This script requires `objdict`: `pip3 install objdict` in your `virtualenv` to make sure you have it installed.
#
# Since this file is located in the `docs` directory, we need to add the project path to `path`.

# %%
import sys
sys.path.append('..')

# %% [markdown]
# Now we'll import our card utilities.

# %%
from cards.utils import *
from os import path

# %% [markdown]
# Let's load all our cards using `iter_cards`.

# %%
cards = list(iter_cards(start_path=path.realpath('../cards/src/main/resources/cards')))

# %% [markdown]
# Let's print a nicely formatted string representing each card. We'll skip the Witchwood uncollectibles because they're not implemented; they just have stubs.

# %%
SETS = frozenset([
    'BASIC',
    'CLASSIC',
    'REWARD',
    'PROMO',
    'MAXXRAMAS',
    'GOBLINS_VS_GNOMES',
    'BLACKROCK_MOUNTAIN',
    'THE_GRAND_TOURNAMENT',
    'LEAGUE_OF_EXPLORERS',
    'THE_OLD_GODS',
    'ONE_NIGHT_IN_KARAZHAN',
    'MEAN_STREETS_OF_GADGETZAN',
    'JOURNEY_TO_UNGORO',
    'KNIGHTS_OF_THE_FROZEN_THRONE',
    'KOBOLDS_AND_CATACOMBS',
    'WITCHWOOD',
    'HALL_OF_FAME',
    'CUSTOM'
])

for (card, filepath) in cards:
    # Skip unimplemented witchwood uncollectibles
    if 'description' not in card:
        card['description'] = ''
    if 'baseManaCost' not in card:
        card['baseManaCost'] = 0
    if not card['collectible'] and 'witchwood/uncollectible' not in filepath \
        and card['set'] in SETS and card['name'] != '':
        desc = (', ' + card['description']) if card['description'] != '' else ''
        if card['type'] == 'MINION':
            print('{0} ({1}) {2}/{3}{4}'.format(card['name'], card['baseManaCost'], card['baseAttack'], card['baseHp'], desc))
        elif card['type'] == 'WEAPON':
            print('{0} ({1}) {2}/{3}{4}'.format(card['name'], card['baseManaCost'], card['damage'], card['durability'],  desc))
        else:
            print('{0} ({1}){2}'.format(card['name'], card['baseManaCost'], desc))
# Out:
# Hyena (2) 2/2
# Snake (1) 1/1
# Wolf (1) 1/1, Charge
# Spellbender (1) 1/3
# Worthless Imp (1) 1/1, You are out of demons! At least there are always imps...
# Conjuring (2), Summon a 6/6 Infernal.
# Infernal (6) 6/6
# Lord Jaraxxus (9)
# Blood Fury (3) 3/8
# Defender (1) 2/1
# Ashbringer (5) 5/3
# Battle Axe (1) 2/2
# Heavy Axe (1) 1/3
# Flame of Azzinoth (1) 2/1
# Whelp (1) 1/1
# Bananas (1), Give a minion +1/+1.
# Imp (1) 1/1
# Squire (1) 2/2
# Emerald Drake (4) 7/6
# Damaged Golem (1) 2/1
# Dream (0), Return a minion to its owner's hand.
# Finkle Einhorn (3) 3/3
# Violet Apprentice (1) 1/1
# Laughing Sister (3) 3/5, Can't be targeted by spells or Hero Powers.
# Ysera Awakens (2), Deal 5 damage to all characters except Ysera.
# Baine Bloodhoof (4) 4/5
# Gnoll (2) 2/2, Taunt
# Murloc (0) 1/1
# Devilsaur (5) 5/5
# Squirrel (1) 1/1
# Nightmare (0), Give a minion +5/+5. At the start of your next turn, destroy it.
# Chicken (0) 1/1, Hey Chicken!
# Nourish (5), Gain 2 Mana Crystals and draw 3 cards.
# Nourish (5), Draw 3 cards.
# 3 damage (2), Deal 3 damage to a minion
# +1/+1 (2), Give your minions +1/+1
# Druid of the Claw (5) 4/6, Taunt
# +4 Health, Taunt (3), +4 Health and Taunt
# Panther (2) 3/2
# +4/+4, Taunt (3), Give a minion +4/+4 and Taunt
# 5 damage single (5), Deal 5 damage to a minion
# 2 damage AoE (5), Deal 2 damage to all enemy minions
# Treant (2) 2/2
# Druid of the Claw (5) 4/6, Taunt
# 7 damage single and 2 damage AoE (5), Deal 7 damage to a minion. Deal 2 damage to all other enemy minions.
# +4 Attack (3), Give a minion +4 Attack
# Summon Panther (2), Summon a 3/2 Panther.
# Nourish (5), Gain 2 Mana Crystals.
# 1 damage + draw card (2), Deal 1 damage to a minion and draw a card.
# Druid of the Claw (5) 4/4, Charge
# Wrath (2), Deal 4 damage to a minion and draw a card.
# Treant (2) 2/2, Taunt
# Summon Panther and +1/+1 (2), Summon a 3/2 Panther. Give your minions +1/+1.
# Fireword (2), Deal 2 damage.
# Shadow of Nothing (0) 0/1, Mindgames whiffed! Your opponent had no minions!
# Flamebreath (2), Deal 3 damage.
# Spirit Wolf (2) 2/3
# Defias Bandit (2) 2/1
# Ragnaros the Firelord (8)
# Whelp (1) 2/1
# Druid of the Flame (3) 5/2
# Druid of the Flame (3) 2/5
# Druid of the Flame (3) 5/5
# DIE, INSECT! (2), Deal 8 damage to a random enemy.
# Tail Swipe (4), Deal 4 damage.
# Timepiece of Horror (10), Deal 10 damage randomly split among all enemies.
# Lantern of Power (10), Give a minion +10/+10.
# Scarab (1) 1/1, Taunt
# Rascally Runt (2) 2/2
# Discover a minion and a spell (1), Discover a minion. Discover a spell.
# Discover a spell (1), Discover a spell.
# Roaring Torch (3), Deal 6 damage.
# Discover a minion (1), Discover a minion.
# Golden Monkey (4) 6/6, Taunt. Battlecry: Replace your hand and deck with Legendary minions.
# Wily Runt (2) 2/2
# Map to the Golden Monkey (2), Shuffle the Golden Monkey into your Deck. Draw a card.
# Mirror of Doom (10), Fill your board with 3/3 Mummy Zombies.
# Ancient Curse (0), When you draw this, take 7 damage and draw a card.
# Cursed! (2), While this is in your hand, take 2 damage at the start of your turn.
# Mummy Zombie (3) 3/3
# Grumbly Runt (2) 2/2
# Huffer (3) 4/2, Charge
# Rexxar (0), Hero Power: Deal 2 damage to the enemy hero
# Misha (3) 4/4, Taunt
# Steady Shot (2), Deal 2 damage to the enemy hero.
# Leokk (3) 2/4, Your other minions have +1 Attack.
# Mirror Image (0) 0/2, Taunt
# Jaina Proudmoore (0), Hero Power: Deal 1 damage to a target
# Fireblast (2), Deal 1 damage.
# Sheep (1) 1/1
# Gul'dan (0), Hero Power: Take 2 damage and draw a card
# Life Tap (2), Take 2 damage and draw a card.
# Uther Lightbringer (0), Hero Power: Summon a 1/1 Silver Hand Recruit
# Reinforce (2), Summon a 1/1 Recruit.
# Recruit (1) 1/1
# Armor Up! (2), Gain 2 Armor.
# Garrosh Hellscream (0), Hero Power: Gain 2 armor
# Mechanical Dragonling (1) 2/1
# The Coin (0), Gain 1 Mana this turn only.
# Boar (1) 1/1
# Murloc Scout (1) 1/1
# Shapeshift (2), +1 Attack this turn. +1 Armor.
# Excess Mana (0), Draw a card. (You can only have 10 Mana in your tray.)
# Malfurion Stormrage (0), Hero Power: Gain 1 armor and +1 Attack this turn
# Heal (2), Restore 2 Health.
# Anduin Wrynn (0), Hero Power: Restore 2 health to a target
# Frog (0) 0/1, Taunt
# Searing Totem (1) 1/1
# Wrath of Air Totem (1) 0/2, Spell Damage +1
# Thrall (0), Hero Power: Summon a random Basic Totem
# Stoneclaw Totem (1) 0/2, Taunt
# Healing Totem (1) 0/2, At the end of your turn, restore 1 Health to all friendly minions.
# Wicked Knife (1) 1/2
# Dagger Mastery (2), Equip a 1/2 Dagger.
# Valeera Sanguinar (0), Hero Power: Equip a 1/2 weapon
# Steward (1) 1/1
# Broom (2) 2/2
# Cellar Spider (3) 1/3
# Sharp Fork (3) 3/2
# Candle (1) 1/1
# Big Bad Wolf (2) 3/2
# Teapot (3) 3/3
# Pawn (1) 1/1, Taunt
# Atiesh (3) 1/3, After you cast a spell, summon a random minion of the same Cost. Lose 1 Durability.
# Animated Shield (2) 0/5, Taunt
# Cat in a Hat (3) 4/2, Stealth
# Armor Plating (1), Give a minion +1 Health.
# Emergency Coolant (1), Freeze a minion.
# Reversing Switch (1), Swap a minion's Attack and Health
# Whirling Blades (1), Give a minion +1 Attack.
# Rusty Horn (1), Give a minion Taunt.
# Time Rewinder (1), Return a friendly minion to your hand.
# Finicky Cloakfield (1), Give a friendly minion Stealth until your next turn.
# Burrowing Mine (0), When you draw this, it explodes. You take 10 damage and draw a card.
# Chicken (1) 1/1
# V-07-TR-0N (8) 4/8, Charge. Mega-Windfury (Can attack four times a turn.)
# Wrathful Spirit (1) 1/1, Deathrattle: Deal 1-4 damage to a random enemy.
# +5/5 and Taunt (6), Summon 5 Wisps and give a minion +5/5 and Taunt
# +5/5 and Taunt (6), +5/5 and Taunt
# Druid Of The Fang (Cobra Form) (5) 7/7
# Summon 5 Wisps (6), Summon 5 Wisps
# Gallywix's Coin (0), Gain 1 Mana this turn only. (Won't trigger Gallywix.)
# Spider (1) 1/1
# Mastiff (1) 1/1
# Icky Tentacle (1) 1/1
# Shadowbeast (1) 1/1
# Soldier (1) 1/1
# The Tidal Hand (2), Summon a 1/1 Murloc.
# Rusty Hook (1) 1/3
# Twin Emperor Vek'nilash (7) 4/6, Taunt.
# Faceless Destroyer (4) 5/5
# Ooze (1) 1/1, Taunt.
# The Ancient One (9) 30/30
# Slime (2) 2/2
# Summon 7 Wisps and give your minions +2/+2 (7), Summon 7 Wisps. Give your minions +2/+2.
# Evolve Spines (3), Gain +4 Attack this turn.
# Give your minions +2/2 (7), Your minions get +2/2
# Evolve Scales (3), Gain 8 Armor.
# Summon 7 Wisps (7), Summon 7 Wisps
# Evolve Spines and Scales (3), Gain 4 Attack and 8 Armor.
# Twilight Elemental (3) 4/2
# Kingsblood Toxin (1), Draw a card.
# Briarthorn Toxin (1), Give a minion +3 Attack.
# Fadeleaf Toxin (1), Give a friendly minion Stealth until your next turn.
# Firebloom Toxin (1), Deal 2 damage.
# Bloodthistle Toxin (1), Return a friendly minion to your hand. It costs (2) less.
# Build-A-Beast (2), Craft a custom Zombeast
# Icy Touch (2), Deal 1 damage. If this kills a minion, summon a Water Elemental.
# Frozen Champion (1) 0/1, Deathrattle: Add a random Legendary minion to your hand.
# Siphon Life (2), Hero Power: Lifesteal. Deal 3 damage.
# Deathlord Nazgrim (2) 2/2
# Darion Mograine (2) 2/2
# Inquisitor Whitemane (2) 2/2
# Thoras Trollbane (2) 2/2
# The Four Horsemen (2), Summon a 2/2 Horseman. If you have all 4, destroy the enemy hero.
# Grave Vengeance (8) 5/3, Lifesteal
# Shadowmourne (8) 4/3, Also damages the minions next to whomever your hero attacks.
# Bladestorm (2), Hero Power: Deal 1 damage to all minions.
# Ghoul (2) 2/2
# Skeletal Enforcer (5) 5/5
# Skeleton (1) 1/1
# Skeletal Flayer (8) 8/8
# Frost Widow (2) 1/2, Poisonous
# Druid of the Swarm (2) 1/5, Taunt.
# Druid of the Swarm (2) 1/5, Taunt. Poisonous.
# Plague Lord Armor (2), Gain 3 Armor
# Plague Lord Attack and Armor (2), +3 Attack this turn and Gain 3 Armor
# Scarab Beetle (2) 1/5, Taunt
# Plague Lord Attack (2), +3 Attack this turn
# Plague Lord (2), Choose One - +3 Attack this turn; or Gain 3 Armor
# Druid of the Swarm (2) 1/2, Poisonous.
# Ghoul Infestor (5) 5/5
# Voidform (2), Deal 2 damage. After you play a card, refresh this.
# Transmute Spirit (2), Hero Power: Transform a friendly minion into a random one that costs (1) more.
# Shadow Reflection (1), Each time you play a card, transform this into a copy of  it.
# Death's Shadow (0), Passive Hero Power. During your turn, add a 'Shadow Reflection' to your hand.
# Obliterate (2), Destroy a minion. Your hero takes damage equal to its Health.
# Anti-Magic Shell (4), Give your minions +2/+2 and "Can't be targeted by spells or Hero Powers."
# Death Grip (2), Steal a minion from your opponent's deck and add it to your hand.
# Doom Pact (5), Destroy all minions. Remove the top card from your deck for each minion destroyed.
# Army of the Dead (6), Remove the top 5 cards of your deck. Summon any minions removed.
# Death Coil (2), Deal 5 damage to an enemy, or restore 5 Health to a friendly character.
# Death and Decay (3), Deal 3 damage to all enemies
# Frostmourne (7) 5/3, Deathrattle: Summon every minion killed by this weapon.
# Wolf (3) 3/3
# Emerald Spellstone (5), Summon three 3/3 Wolves. (Play a Secret to upgrade.)
# Greater Emerald Spellstone (5), Summon four 3/3 Wolves.
# Greater Ruby Spellstone (2), Add 3 random Mage spells to your hand.
# Scroll of Wonder (5), Cast a random spell. Draw a card. Cast this when drawn.
# Fire Dragon (5) 5/5
# Ruby Spellstone (2), Add 2 random Mage spells to your hand. (Play 2 Elementals to upgrade.)
# Amethyst Spellstone (4), Lifesteal. Deal 5 damage to a minion. (Take damage from your cards to upgrade.)
# Felhunter (2) 2/2
# The First Seal (5), Summon a 2/2 Demon. Add 'The Second Seal' to your hand.
# The Second Seal (5), Summon a 3/3 Demon. Add 'The Third Seal' to your hand.
# The Fourth Seal (5), Summon a 5/5 Demon. Add 'The Final Seal' to your hand.
# The Third Seal (5), Summon a 4/4 Demon. Add 'The Fourth Seal' to your hand.
# The Final Seal (5), Summon a 6/6 Demon. Add 'Azari, the Devourer' to your hand.
# Greater Amethyst Spellstone (4), Lifesteal. Deal 7 damage to a minion.
# Azari, the Devourer (10) 10/10, Battlecry: Destroy your opponent's deck.
# Felhunter (5) 5/5
# Felhunter (3) 3/3
# Felhunter (6) 6/6
# Felhunter (4) 4/4
# Champion's Maul (3) 2/2, Battlecry: Summon two 1/1 Silver Hand Recruits.
# Blessed Maul (3) 2/2, Give your minions +1 Attack.
# Purifier's Maul (3) 2/2, Battlecry: Give your minions Divine Shield.
# Guardian Spirit (2) 2/2, Taunt
# Guardian Spirit (4) 4/4, Taunt
# Greater Pearl Spellstone (5), Summon a 6/6 Spirit with Taunt.
# Pearl Spellstone (2), Summon a 4/4 Spirit with Taunt. (Restore 3 Health to upgrade.)
# Guardian Spirit (6) 6/6, Taunt
# Sacred Maul (3) 2/2, Battlecry: Give your minions Taunt.
# Tower Shield +10 (6), Gain 5 Armor. Gain 10 more Armor.
# Iron Golem (5) 5/5
# Spiked Shield (6), Gain 5 Armor. Equip a 5/2 weapon.
# Mithril Spellstone (7), Summon two 5/5 Mithril Golems. (Equip a weapon to upgrade.)
# Serrated Shield (6), Gain 5 Armor. Deal 5 damage.
# Greater Mithril Spellstone (7), Summon three 5/5 Mithril Golems.
# Spiked Shield (5) 5/2
# Runed Shield (6), Gain 5 Armor. Summon a 5/5 Golem.
# Master Chest (3) 0/8, Deathrattle: Give your opponent a fantastic treasure!
# Golden Kobold (3) 6/6, Taunt. Battlecry: Replace your hand with Legendary minions.
# King's Ransom (5), Swap decks with your opponent.
# Tolin's Goblet (3), Draw a card. Fill your hand with copies of it.
# Wondrous Wand (3), Draw 3 cards. Reduce their Costs to (0).
# Zarog's Crown (3), Discover a Legendary minion. Summon two copies of it.
# Giant Rat (3) 2/3
# Grub (1) 1/1
# Green Ooze (1) 1/2, Taunt
# Darkness Candle (4), Snuff out a candle. Draw a card. Cast this when drawn.
# Cursed Revenant (4) 5/1
# Moss Elemental (6) 6/6
# Greater Jasper Spellstone (1), Deal 6 damage to a minion.
# Jasper Spellstone (1), Deal 4 damage to a minion. (Gain 3 Armor to upgrade.)
# Which Paths Will You Take (0)
# Elixir of Shadows (3), Give a minion +2/+2. Summon a 1/1 copy of it.
# Dragon Spirit (5) 5/5
# Diamond Spellstone (7), Resurrect 3 different friendly minions. (Cast 4 spells to upgrade.)
# Elixir of Purity (3), Give a minion +2/+2 and Divine Shield.
# Elixir of Life (3), Give a minion +2/+2 and Lifesteal.
# Elixir of Hope (3), Give a minion +2/+2 and "Deathrattle: Return this minion to your hand."
# Greater Diamond Spellstone (7), Resurrect 4 different friendly minions.
# Greater Sapphire Spellstone (7), Summon 3 copies of a friendly minion.
# Sapphire Spellstone (7), Summon 2 copies of a friendly minion. (Overload 3 Mana Crystals to upgrade.)
# Onyx Spellstone (5), Destroy up to 2 random enemy minions. (Play 3 Deathrattle cards to upgrade.)
# Leyline Spider (4) 4/4
# Spider Ambush! (0), Summon a 4/4 Spider. Draw a card. Cast this when drawn.
# Greater Onyx Spellstone (5), Destroy up to 3 random enemy minions.
# Raptor Patriarch (1) 4/3
# Queen Carnassa (5) 8/8, Battlecry: Shuffle 15 Raptors into your deck.
# Carnassa's Brood (1) 3/2, Battlecry: Draw a card.
# Dinomancy (2), Give a Beast +2/+2
# Pyros (10) 10/10
# Pyros (6) 6/6, Deathrattle: Return this to your hand as a 10/10 that costs (10).
# Time Warp (5), Take an extra turn.
# Nether Portal (5), Open a permanent portal that summons 3/2 Imps.
# Imp (1) 3/2
# Nether Portal (0) 0/1, Permanent. At the end of your turn, summon two 3/2 Imps.
# Pterrordax (1) 1/1
# Adapt (0)
# Galvadon (5) 5/5, Battlecry: Adapt 5 times.
# Sulfuras (3) 4/2, Battlecry: Your Hero Power becomes 'Deal 8 damage to a random enemy.'
# Choose Your Path (1), Discover a card.
# Direhorn Matriarch (5) 6/9, Taunt
# Owl Monkey (1) 1/2
# Primalfin (1) 1/1
# Shellshifter (4) 5/5, Taunt, Stealth.
# Raptor (1) 1/1
# Un'Goro Pack (2), Add 5 Journey to Un'Goro cards to your hand.
# Flame Elemental (1) 1/2
# Shellshifter (4) 3/5, Taunt
# Mana Treant (2) 2/2, Deathrattle: Gain an empty Mana Crystal.
# Shellshifter (4) 5/3, Stealth
# Barnabus the Stomper (5) 8/8, Battlecry: Reduce the Cost of minions in your deck to (0).
# Shellshifter (4) 5/5, Stealth. Taunt.
# Amara, Warden of Hope (5) 8/8, Taunt. Battlecry: Set your hero's Health to 40'.
# Invocation of Air (0), Fill your board with 1/1 Elementals.
# Invocation of Fire (0), Fill your board with 1/1 Elementals.
# Invocation of Water (0), Restore 12 Health to your hero.
# Stone Elemental (2) 2/3, Taunt
# Stone Elemental (1) 1/1
# Invocation of Air (0), Deal 3 damage to all enemy minions.
# Megafin (5) 8/8, Battlecry: Fill your hand with random Murlocs.
# Razorpetal (1), Deal 1 damage.
# Sherazin, Seed (0) 0/1, Permanent. When you play 4 cards in a turn, revive this minion.
# Crystal Core (5), For the rest of the game, your minions are 5/5.
# Katanaka (2), Deal 3 damage to the enemy hero.
# Boar (3) 4/2, Charge
# Chi Blast (2), Deal 2 damage.
# Soul Tap (2), Draw a card.
# Mass Conscription (2), Summon two 1/1 Recruits.
# Tank Up! (2), Gain 4 Armor.
# War Kodo (3) 3/5
# Nightmarish Hanger (2), Gain 2 Armor and +2 Attack this turn.
# Sapling (1) 1/1
# Deal 2 damage and summon two 1/1 (1), Deal 2 damage. Summon two 1/1 Saplings.
# Summon two 1/1 (1), Summon two 1/1 Saplings
# Sabertooth Lion (2) 2/1, Charge
# Sabertooth Panther (2) 3/2, Stealth
# 2 damage (1), Deal 2 damage
# Sabertooth Tiger (2) 3/2, Charge, Stealth
# Heal (2), Restore 4 Health.
# Healing Totem (2), Summon a Healing Totem.
# Katana (2), Deal 2 damage.
# Wrath of Air Totem (2), Summon a Wrath of Air Totem.
# Stoneclaw Totem (2), Summon a Stoneclaw Totem.
# Greater Conjuring (2), Summon a Minor Creature of your choice.
# Searing Totem (2), Summon a Searing Totem.
# Ambush! (0), When you draw this, summon a 4/4 Nerubian for your opponent. Draw a card.
# Poisoned Blade (1) 2/2
# Poisoned Blade (2), Equip a 2/2 Dagger.
# Piranha (1) 1/1
# Tabbycat (1) 1/1
# Cat (1) 1/1
# Baaraxxus (1)
# Sheep (1) 1/1
# Kabal Demon (2) 2/2
# Kabal Demon (8) 8/8
# Kabal Demon (5) 5/5
# "Little Friend" (6) 6/6
# Jade Idol (1), Summon a Jade Golem.
# Jade Idol (1), Summon a Jade Golem. Shuffle 3 copies of this card into your deck.
# Jade Idol (1), Shuffle 3 copies of this into your deck.
# Crystal (2) 2/2
# The Storm Guardian (5) 10/10, Taunt.
# Murloc Razorgill (1) 1/1
# Repair Bot (1) 0/3, At the end of your turn, restore 6 Health to a damaged character.
# Emboldener 3000 (1) 0/4, At the end of your turn, give a random minion +1/+1.
# Power of the Horde (4), Summon a random Horde Warrior.
# I Am Murloc (4), Summon three, four, or five 1/1 Murloc.
# Rogues Do it... (4), Deal 4 damage. Draw a card.
# Homing Chicken (1) 0/1, At the start of your turn, destroy this minion and draw 3 cards.
# Poultryizer (1) 0/3, At the start of your turn, transform a random minion into a 1/1 Chicken.
# Firestrike (2), Deal 2 damage.
# Flamebreath (2), Deal 3 damage.
# Extra Ingredient (0), Draw a card.
# Fel Giant (20) 8/8, Costs (1) less for each damage your hero has taken.
# Survival Knife (1) 1/1
# Mystic Skull (1), Return a friendly minion to your hand. Change its attack to 5.
# Clown Fiesta (6), Cast Pyroblast, Meteor, Fireball, or Felfire Potion with random targets. Draw a card. Cast this when drawn.
# 4 damage (3), Deal 4 damage
# Cybernetic Rager (3) 15/1
# Summon two 2/2 (3), Summon two 2/2 Treants
# Average Joe (0), Battlecry: Discover your Adventure Boss.
# Deal 4 damage and summon two 2/2 (3), Deal 4 damage. Summon two 2/2 Treants.
# Exampler (1) 4/4, Battlecry: Summon a 5/5 Skeleton for your opponent
# Crazed Dancer (1) 2/2
# Unnerfed Keeper of the Grove (4) 2/4, Choose One - Deal 2 damage; or Silence a minion.
# Unnerfed Abusive Sergeant (1) 2/1, Battlecry: Give a minion +2 Attack this turn.
# Unnerfed Flare (1), All minions lose Stealth. Destroy all enemy Secrets. Draw a card.
# Unnerfed Shiv (1), Deal 1 damage. Draw a card.
# Unnerfed Novice Engineer (2) 1/2, Battlecry: Draw a card.
# Unnerfed Mind Control (8), Take control of an enemy minion.
# Unnerfed Shattered Sun Cleric (3) 3/3, Battlecry: Give a friendly minion +1/+1
# Unnerfed Backstab (0), Deal 2 damage to a minion.
# Unnerfed Big Game Hunter (3) 4/2, Battlecry: Destroy a minion with an Attack of 7 or more.
# Unnerfed Frost Nova (2), Freeze all enemy minions.
# Unnerfed Claw (1), Give your hero +3 Attack this turn
# Unnerfed Ancient of Lore (7) 5/5, Choose One - Draw 2 cards; or Restore 8 Health.
# Unnerfed Pyroblast (8), Deal 10 damage.
# Unnerfed Cenarius (8) 5/8, Choose One - Give your other minions +2/+2; or Summon two 2/2 Treants with Taunt.
# Unnerfed Rockbiter Weapon (1), Give a friendly character +3 Attack this turn.
# Unnerfed Argent Commander (6) 4/3, Charge, Divine Shield
# Unnerfed Soulfire (0), Deal 4 damage. Discard a random card.
# Unnerfed Druid of the Claw (CatBear) (5) 4/7, Charge. Taunt
# Unnerfed Cone of Cold (3), Freeze a minion and the minions next to it, and deal 1 damage to them.
# Unnerfed Dark Iron Dwarf (4) 4/4, Battlecry: Give a minion +2 Attack.
# Unnerfed Dalaran Mage (3) 2/4, Spell Damage +1
# Unnerfed Druid of the Claw (Bear) (5) 4/7, Taunt
# Unnerfed Stormwind Champion (6) 6/6, Your other minions have +1/+1.
# Unnerfed Druid of the Claw (5) 4/4, Choose One - Charge; or +3 Health and Taunt.
# Unleash the Hounds (3), Give your Beasts +1 Attack and Charge.
# Unnerfed Cult Master (4) 3/4, Whenever one of your other minions dies, draw a card.
# Plan Your Attack! (0)
# Hurricane Totem (2) 0/4, Spell Damage +2
# Magmatic Totem (2) 2/2, Your Totems have +1 Attack during your opponent's turn.
# Earthbound Totem (2) 0/4, Taunt. Divine Shield.
# Sun and Earth Totem (2) 0/4, At the end of your turn, restore 2 Health to all friendly minions.
# Evocation (3), Gain 4 Mana Crystals this turn only.
# SURPRISE, INSECT! (3), Secret: When your opponent ends their turn, replace your hero with Ragnaros the Firelord.
# The Codex of Xerrath (5), For the rest of the game, friendly characters are immune during your turn. Summon a Doomguard.
# The Black Harvest (1), Quest: Summon 4 Demons. Reward: The Codex of Xerrath.
# Seek the Signal (1), Quest: Cast 3 Spells. Reward: The Black Harvest.
# Power Word: Fortitude (2), Give a character +5 health.
# Ragnaros the Gravelord (8) 8/8, At the end of your turn, summon a random friendly minion that died this game.
# Bronze Drake (3) 3/3, Deathrattle: If you're holding a Dragon, draw a card.
# Vision of Doom (7), Transform a minion into a Doomsayer
# Vampiric Touch (2), Deal 2 damage to a minion. If that kills it, summon a 1/1 copy of it.
# Hunter Secret (0), Receive a random Hunter secret
# Paladin Secret (0), Receive a random Paladin secret
# Mage Secret (0), Receive a random Mage secret
# Rogue Secret (0), Receive a random Rogue secret
